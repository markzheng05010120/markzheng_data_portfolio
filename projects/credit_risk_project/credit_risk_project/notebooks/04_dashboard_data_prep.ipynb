# %% [markdown]
# # Week20 - Dashboard Data Preparation
#
# ## Goal
# Prepare clean and simple data files for the future Tableau dashboard.
#
# ## Why This Step Matters
# This step organizes the key analysis results into dashboard-ready tables.
# These files will be used in Tableau in the next stage.

# %%
import pandas as pd

# %%
clean_df = pd.read_csv('credit_risk_cleaned.csv')

# %%
clean_df['burden_group'] = pd.qcut(
    clean_df['loan_percent_income'],
    q=3,
    labels=['low_burden', 'medium_burden', 'high_burden']
)

# %%
dashboard_detail = clean_df[[
    'person_age',
    'person_income',
    'person_home_ownership',
    'person_emp_length',
    'loan_intent',
    'loan_grade',
    'loan_amnt',
    'loan_int_rate',
    'loan_status',
    'loan_percent_income',
    'cb_person_default_on_file',
    'cb_person_cred_hist_length',
    'burden_group'
]].copy()

dashboard_detail.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          21           9600                   OWN                5.0
# 1          25           9600              MORTGAGE                1.0
# 2          23          65500                  RENT                4.0
# 3          24          54400                  RENT                8.0
# 4          21           9900                   OWN                2.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0   EDUCATION          B       1000          11.14            0
# 1     MEDICAL          C       5500          12.87            1
# 2     MEDICAL          C      35000          15.23            1
# 3     MEDICAL          C      35000          14.27            1
# 4     VENTURE          A       2500           7.14            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length  \
# 0                 0.10                         N                           2
# ...

# %%
dashboard_detail.to_csv('dashboard_detail.csv', index=False)

# %%
dashboard_summary = pd.DataFrame({
    'metric': [
        'overall_default_rate',
        'average_income',
        'average_loan_amount',
        'average_interest_rate',
        'average_loan_percent_income'
    ],
    'value': [
        clean_df['loan_status'].mean(),
        clean_df['person_income'].mean(),
        clean_df['loan_amnt'].mean(),
        clean_df['loan_int_rate'].mean(),
        clean_df['loan_percent_income'].mean()
    ]
})

dashboard_summary
# Out:
#                         metric         value
# 0         overall_default_rate      0.218180
# 1               average_income  65878.480813
# 2          average_loan_amount   9588.018051
# 3        average_interest_rate     11.009470
# 4  average_loan_percent_income      0.170202

# %%
dashboard_summary.to_csv('dashboard_summary.csv', index=False)
